# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("zellkonverter")
# Out:
# Bioconductor version '3.22' is out-of-date; the current release version '3.23'
#   is available with R version '4.6'; see https://bioconductor.org/install
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# Installing package(s) 'zellkonverter'
#
# also installing the dependencies ‘dir.expiry’, ‘basilisk’
# The downloaded binary packages are in
# 	/var/folders/lk/54m90rgj1fqg895lxsgx1l180000gn/T//Rtmp2v7iNu/downloaded_packages
# Old packages: 'ComplexHeatmap', 'DBI', 'DelayedArray', 'GenomeInfoDb',
#   'GenomicRanges', 'GetoptLong', 'GlobalOptions', 'Matrix', 'RCurl', 'RSQLite',
#   'Rcpp', 'RcppArmadillo', 'RcppRoll', 'Rdpack', 'S4Arrays', 'S4Vectors', 'S7',
#   'Seurat', 'SeuratObject', 'Signac', 'SparseArray', 'TFMPvalue', 'UCSC.utils',
# ...

# %%
library(Seurat)
library(zellkonverter)
library(SingleCellExperiment)

# %%
# 1. Load Data
sc_obj <- readRDS("Seurat_Clusters.rds")

# %%
# 3. CRITICAL FOR SEURAT V5: Join layers before conversion
sc_obj <- JoinLayers(sc_obj)

# 4. Convert to SingleCellExperiment, then to .h5ad
sce <- as.SingleCellExperiment(sc_obj)
writeH5AD(sce, file = "sc_reference.h5ad")

print("Prep complete: sc_reference.h5ad saved.")
# Out:
# For native R and reading and writing of H5AD files, an R <AnnData> object, and
# conversion to <SingleCellExperiment> or <Seurat> objects, check out the
# anndataR package:
# ℹ Install it from Bioconductor with `BiocManager::install("anndataR")`
# ℹ See more at <https://bioconductor.org/packages/anndataR/>
# This message is displayed once per session.
# Installing pyenv ...
# Done! pyenv has been installed to '/Users/romanperikzavodskii/Library/Application Support/r-reticulate/pyenv/bin/pyenv'.
# Using Python: /Users/romanperikzavodskii/.pyenv/versions/3.14.0/bin/python3.14
# Creating virtual environment '/Users/romanperikzavodskii/Library/Caches/org.R-project.R/R/basilisk/1.22.0/zellkonverter/1.20.1/zellkonverterAnnDataEnv-0.12.3' ...
# + /Users/romanperikzavodskii/.pyenv/versions/3.14.0/bin/python3.14 -m venv /Users/romanperikzavodskii/Library/Caches/org.R-project.R/R/basilisk/1.22.0/zellkonverter/1.20.1/zellkonverterAnnDataEnv-0.12.3
# Done!
# ...
